# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # SAMRIDDHYA RAY CHOWDHURY

# %% [markdown]
# # DATA SCIENTIST

# %% [markdown]
# # I am interested in Data Science because data can speak and i like communicating through it.

# %% [markdown]
# ### multiplicatio of two given numbers

# %%
number1=2

# %%
number2=5

# %%
result=int(2*5)

# %%
print(result)
# Out:
# 10

# %% [markdown]
# ![1041869.jpg](attachment:1041869.jpg)

# %% [markdown]
# 1. 1984
# 2. 1987
# 3. 1992
# 4. 1996

# %% [markdown]
# https://upload.wikimedia.org/wikipedia/commons/thumb/3/38/Jupyter_logo.svg/800px-Jupyter_logo.svg.png
